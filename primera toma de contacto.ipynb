# %% [markdown]
# LLIBERTAT PRESUS POLITICS

# %% [markdown]
# **Diseñar y presentar una solución analítica end-to-end que permita a FinPlus:**
#
# 1. **Comprender mejor su base de clientes**, incluyendo perfilado, segmentación y análisis de hábitos.
# 2. **Identificar patrones de comportamiento clave**, como uso de productos, niveles de actividad e interacción con los canales.
# 3. **Detectar riesgos de abandono o pérdida de rentabilidad**, a través de modelos predictivos y alertas tempranas.
# 4. **Encontrar oportunidades de crecimiento**, especialmente en estrategias de *cross-selling*, *up-selling* y aumento del engagement.
# 5. **Proponer indicadores (KPIs) y visualizaciones** que faciliten la toma de decisiones y el monitoreo continuo del negocio.

# %%
#Importo las librerías necesarias
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql import Window

# %%
# Crear la sesión de Spark
spark = SparkSession.builder \
    .appName("ProyectoFinPlus_PySpark") \
    .getOrCreate()

sc = spark.sparkContext

DATA_PATH = ""

# %%
# Crea la ruta al archivo
DATA_PATH_DIR = "/home/jovyan/data/"
DATA_FILE = "BEHAVIOURAL_1.csv"

# La ruta completa que Spark debe usar
DATA_PATH = DATA_PATH_DIR + DATA_FILE 

# Puedes verificar la ruta:
print(DATA_PATH) 
# Esperado: /home/jovyan/data/BEHAVIOURAL_1.csv
# Out:
# /home/jovyan/data/BEHAVIOURAL_1.csv

# %%
import os

# La ruta absoluta DENTRO del contenedor Docker donde se montaron los datos


# Cargar los datos

print("Leyendo desde:", DATA_PATH)

df = (
    spark.read.option('header', 'true')
    .option('delimiter', ';')
)   .csv(DATA_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       1 import os
#       3 # La ruta absoluta DENTRO del contenedor Docker donde se montaron los datos
#       4
#       5
#       6 # Cargar los datos
# ----> 8 print("Leyendo desde:", data_path)
#      10 df = (
#      11     spark.read.option('header', 'true')
#      12     .option('delimiter', ';')
#      13 )   .csv(DATA_PATH)
#
# NameError: name 'data_path' is not defined

# %%
## Leer el csv de BEHAVIOURAL_1.csv con inferencia de esquema y mostrar las primeras 5 filas sin truncar
spark.read.csv(
    DATA_PATH + "BEHAVIOURAL_1.csv", 
    header=True, 
    inferSchema=True)\
.show(5,0)
df1.printSchema()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 ## Leer el csv de BEHAVIOURAL_1.csv con inferencia de esquema y mostrar las primeras 5 filas sin truncar
# ----> 2 spark.read.csv(
#       3     DATA_PATH + "BEHAVIOURAL_1.csv",
#       4     header=True,
#       5     inferSchema=True)\
#       6 .show(5,0)
#       7 df1.printSchema()
#
# ...

# %%
## Leer el CSV de BEHAVIOURAL_2.csv con inferencia de esquema y mostrar las primeras 5 filas sin truncar
spark.read.csv(
    DATA_PATH + "BEHAVIOURAL_2.csv", 
    header=True, 
    inferSchema=True)\
.show(5,0)
df1.printSchema()
# Out:
# +------------------+------------+----------+--------------------+-----------------+------------------------+--------------------+------------------------+--------------------------+-------------------+-------------------+---------------+------------------+--------+
# |CONTRACT_ID       |CLIENT_ID   |DATE      |CREDICT_CARD_BALANCE|CREDIT_CARD_LIMIT|CREDIT_CARD_DRAWINGS_ATM|CREDIT_CARD_DRAWINGS|CREDIT_CARD_DRAWINGS_POS|CREDIT_CARD_DRAWINGS_OTHER|CREDIT_CARD_PAYMENT|NUMBER_DRAWINGS_ATM|NUMBER_DRAWINGS|NUMBER_INSTALMENTS|CURRENCY|
# +------------------+------------+----------+--------------------+-----------------+------------------------+--------------------+------------------------+--------------------------+-------------------+-------------------+---------------+------------------+--------+
# ...

# %%
## Leer el CSV de CLIENTS.csv con inferencia de esquema y mostrar las primeras 5 filas sin truncar
spark.read.csv(
    DATA_PATH + "CLIENTS.csv", 
    header=True, 
    inferSchema=True)\
.show(5,0)
df1.printSchema()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 ## Leer el CSV de CLIENTS.csv con inferencia de esquema y mostrar las primeras 5 filas sin truncar
# ----> 2 spark.read.csv(
#       3     DATA_PATH + "CLIENTS.csv",
#       4     header=True,
#       5     inferSchema=True)\
#       6 .show(5,0)
#       7 df1.printSchema()
#
# ...

# %%
# instalar el motor para leer .xlsx si no está disponible y usar pandas para leer el Excel
# %pip install openpyxl

import pandas as pd

# Leer un archivo Excel con pandas y convertirlo a DataFrame de Spark
pd_df = pd.read_excel(DATA_PATH + "Data_Dictionary.xlsx", engine="openpyxl")
df_dd = spark.createDataFrame(pd_df)

df_dd.show(5, 0)
df_dd.printSchema()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# +----------+----------------+--------------+-------------------------------------------+-------------------------------------------+
# |Table     |Information type|Field         |Description                                |Description.1                              |
# +----------+----------------+--------------+-------------------------------------------+-------------------------------------------+
# |CLIENT.CSV|ID              |CLIENT_ID     |ID único del cliente                       |Unique ID of the customer                  |
# |CLIENT.CSV|Demographic     |CURRENCY      |divisa del movimiento/préstamo/importe     |currency of the movement/loan/amount       |
# |CLIENT.CSV|Demographic     |GENDER        |sexo del cliente (F: mujer, M: hombre)     |gender of the customer (F: female, M: male)|
# ...
